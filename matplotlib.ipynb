# %%
import matplotlib.pyplot as plt
import numpy as np
x=([45,78])
y=([89,99])
print(plt.plot(x,y,marker='d'))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x7f6fa85eb670>]
# None

# %%
import matplotlib.pyplot as plt
import numpy as np
x=([23,45,67,89])
y=([34,22,55,77])
plt.plot(x,y,marker='D')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=([78,99])
plt.plot(y,marker='H')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=([45,66,77,99,34])
plt.plot(ypoints,linestyle='dashed')
plt.title('Sample Graph')
plt.xlabel('xaxis')
plt.ylabel('yaxis')
# Out:
# Text(0, 0.5, 'yaxis')

# %%
import matplotlib.pyplot as plt
import numpy as np
x=([45,33,21,67])
y=([90,89,7,8])
plt.plot(x,y,linestyle='dotted')
plt.show()

# %%
 import matplotlib.pyplot as plt
 import numpy as np
 y=([78,89,54,32])
 plt.plot(y,linewidth='0.6',color='b')
 plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=([24,26,28,30])
y=([50,52,54,56])
plt.plot(x)
plt.plot(y)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=([34,36,38,40])
y=([90,92,94,95])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=([43,44,54,56])
y=([45,78,89,45])
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=([1,1,1,3])
y=([1,3,5,3])
plt.plot(x,y)
a=([5,5,5,3])
b=([1,3,5,3])
plt.plot(a,b)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=([12,23,36,54])
y=([23,34,45,57])
plt.
